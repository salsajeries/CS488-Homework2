# %% [markdown]
# <a href="https://colab.research.google.com/github/salsajeries/CS488-Homework2/blob/main/regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.linear_model import LinearRegression
from sklearn. model_selection import train_test_split
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load Iris Data
iris = load_iris()

# Creating pd DataFrames
iris_df = pd.DataFrame(data= iris.data, columns= iris.feature_names)
target_df = pd.DataFrame(data= iris. target, columns= ['species'])

#generate labels
def converter(specie):
  if specie == 0:
    return 'setosa'
  elif specie == 1:
    return 'versicolor'
  else:
    return 'virginica'

target_df['species'] = target_df['species'].apply(converter)

# Concatenate the DataFrames
iris_df = pd.concat([iris_df, target_df], axis= 1)

# iris data statistics
iris_df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Converting Objects to Numerical dtype
iris_df.drop('species', axis= 1, inplace= True)
target_df = pd.DataFrame(columns= ['species'], data= iris.target)
iris_df = pd.concat([iris_df, target_df], axis= 1)

# Variables
X= iris_df.drop(labels= 'petal length (cm)', axis= 1)
y= iris_df['petal length (cm)']

# Splitting the Dataset
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2, random_state= 111)  # Train size 80%, test size 20%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.8, random_state= 111) # Train size 20%, test size 80%

# %%
# linear regression-LR model
lr = LinearRegression()

# Fit LR Model
lr.fit(X_train, y_train)

# LR prediction
lr. predict (X_test)
y_pred = lr. predict(X_test)

# Quantitaive analysis - evaluate LR performance

# LR coefficients- beta/slope
print('LR beta/slope Coefficient:', lr.coef_)

# LR coefficients- alpha/slope_intercept
print('LR alpha/slope intercept Coefficient:', lr.intercept_)

# coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: ', r2_score(y_test, y_pred))

# Model perfermance - error
print('Root Mean Squared Error (RMSE):', np.sqrt(mean_squared_error(y_test, y_pred)))
print('Mean Squared Error (MSE):', mean_squared_error(y_test, y_pred))
# Out:
# LR beta/slope Coefficient: [ 0.44619019 -0.72846544  1.17305908  0.52411613]
# LR alpha/slope intercept Coefficient: 1.4755239625135879
# Coefficient of determination:  0.9578899641296392
# Root Mean Squared Error (RMSE): 0.3502997733681421
# Mean Squared Error (MSE): 0.1227099312217717

# %%
# Predict a new datapoint

# Select any datapoint to predict
iris_df.loc[121]
# Out:
# sepal length (cm)    5.6
# sepal width (cm)     2.8
# petal length (cm)    4.9
# petal width (cm)     2.0
# species              2.0
# Name: 121, dtype: float64

# %%
# Create a new dataframe
d = {'sepal length (cm)' : [5.6],
     'sepal width (cm)' : [2.8],
     'petal length (cm)' : [4.9],
     'petal width (cm)' : [2.0],
     'species' : 0}
pred_df = pd.DataFrame(data= d)

# Display the dataframe
pred_df
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.6               2.8                4.9               2.0
#
#    species
# 0        0

# %%
# Predict the new data point using LR
pred = lr.predict(X_test)
pred
print('Predicted Petal Length (cm):', pred[0])
print('Actual Petal Length (cm):', 4.9)
# Out:
# Predicted Petal Length (cm): 1.5089232374197254
# Actual Petal Length (cm): 4.9
